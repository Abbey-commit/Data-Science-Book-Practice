# %% [markdown]
# # Analyze and Visualize the Data using Python:

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# %%
# Create a connection to the SQLite database
conn = sqlite3.connect('epl_data.db')

# %%
# Load the data into DataFrames
top_home_teams = pd.read_sql("SELECT HomeTeam, SUM(FTHG) AS TotalHomeGoals FROM epl GROUP BY HomeTeam ORDER BY TotalHomeGoals DESC LIMIT 5", conn)
top_away_teams = pd.read_sql('SELECT AwayTeam, SUM(FTAG) AS TotalAwayGoals FROM epl GROUP BY AwayTeam ORDER BY TotalAwayGoals DESC LIMIT 5', conn)
top_referees = pd.read_sql('SELECT Referee, COUNT(*) AS MatchesOfficiated FROM epl GROUP BY  Referee ORDER BY MatchesOfficiated DESC LIMIT 5', conn)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Load the data into DataFrames
# ----> 2 top_home_teams = pd.read_sql("SELECT HomeTeam, SUM(FTHG) AS TotalHomeGoals FROM epl GROUP BY HomeTeam ORDER BY TotalHomeGoals DESC LIMIT 5", conn)
#       3 top_away_teams = pd.read_sql('SELECT AwayTeam, SUM(FTAG) AS TotalAwayGoals FROM epl GROUP BY AwayTeam ORDER BY TotalAwayGoals DESC LIMIT 5', conn)
#       4 top_referees = pd.read_sql('SELECT Referee, COUNT(*) AS MatchesOfficiated FROM epl GROUP BY  Referee ORDER BY MatchesOfficiated DESC LIMIT 5', conn)
#
# File ~\anaconda3\anaconda-3\Lib\site-packages\pandas\io\sql.py:654, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     652 with pandasSQL_builder(con) as pandas_sql:
#     653     if isinstance(pandas_sql, SQLiteDatabase):
# --> 654         return pandas_sql.read_query(
#     655             sql,
#     656             index_col=index_col,
#     657             params=params,
#     658             coerce_float=coerce_float,
#     659             parse_dates=parse_dates,
#     660             chunksize=chunksize,
#     661             dtype_backend=dtype_backend,
#     662             dtype=dtype,
#     663         )
#     665     try:
#     666         _is_table_name = pandas_sql.has_table(sql)
#
# File ~\anaconda3\anaconda-3\Lib\site-packages\pandas\io\sql.py:2326, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2315 def read_query(
#    2316     self,
#    2317     sql,
#    (...)
#    2324     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2325 ) -> DataFrame | Iterator[DataFrame]:
# -> 2326     cursor = self.execute(sql, params)
#    2327     columns = [col_desc[0] for col_desc in cursor.description]
#    2329     if chunksize is not None:
#
# File ~\anaconda3\anaconda-3\Lib\site-packages\pandas\io\sql.py:2260, in SQLiteDatabase.execute(self, sql, params)
#    2258     raise TypeError("Query must be a string unless using sqlalchemy.")
#    2259 args = [] if params is None else [params]
# -> 2260 cur = self.con.cursor()
#    2261 try:
#    2262     cur.execute(sql, *args)
#
# ProgrammingError: Cannot operate on a closed database.

# %%
# Close the connection
conn.close()

# %%
# Set style
sns.set_style('whitegrid')

# %%
# Plot top 5 teams with the most goals scored at home
plt.figure(figsize=(10, 5))
sns.barplot(x='TotalHomeGoals', y='HomeTeam', data=top_home_teams, palette='viridis')
plt.title('Top 5 Teams with the Most Goals Scored at Home')
plt.xlabel('Total Home Goals')
plt.ylabel('Home Team')
plt.show();
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9296\38063289.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='TotalHomeGoals', y='HomeTeam', data=top_home_teams, palette='viridis')

# %%
# Plot top 5 teams with the most goals scored away
plt.figure(figsize=(10, 5))
sns.barplot(x='TotalAwayGoals', y='AwayTeam', data=top_away_teams, palette='magma')
plt.title('Top 5 Teams with the Most Goals Scored Away')
plt.xlabel('Total Away Goals')
plt.ylabel('Away Team')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9296\3959397437.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='TotalAwayGoals', y='AwayTeam', data=top_away_teams, palette='magma')

# %%
# Plot top 5 referees who officiated the most matches
plt.figure(figsize=(10, 5))
sns.barplot(x='MatchesOfficiated', y='Referee', data=top_referees, palette='coolwarm')
plt.title('Top 5 Referees Who Officiated the Most Matches')
plt.xlabel('Matches Officiated')
plt.ylabel('Referees')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 # Plot top 5 referees who officiated the most matches
#       2 plt.figure(figsize=(10, 5))
# ----> 3 sns.barplot(x='MatchesOfficiated', y='Referee', data=top_referees, palette='coolwarm')
#       4 plt.title('Top 5 Referees Who Officiated the Most Matches')
#       5 plt.xlabel('Matches Officiated')
#
# NameError: name 'top_referees' is not defined
